# %%
# test src rec module
#fsr = "temp/src_rec.dat"
fsr = "jpn/src_rec_California_Nevada_single_event.txt"
#fsr = "jpn/src_rec_California_Nevada.txt"


# read src_rec file
import pytomoatt.src_rec as pta_sr

SR = pta_sr.SrcRec.read(fsr, dist_in_data=True, name_net_and_sta=True)

SR
# Out:
# /home/mnagaso/workspace/PyTomoATT/pytomoatt/src_rec.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sr.src_points.loc[:, last_col+1] = 1.0
# PyTomoATT SrcRec Object:
#                 fname=jpn/src_rec_California_Nevada.txt,
#                 src_only=False,
#                 number of sources=249838,
#                 number of receivers=5020618

# %%
SR.src_points
# Out:
#                       origin_time     evla      evlo   evdp   mag  num_rec  \
# src_index
# 0         2014-04-19 10:25:48.890  31.0438 -115.2520  18.56  3.01        2
# 1         2018-08-13 11:52:13.210  31.0542 -116.6508   5.61  3.26        1
# 2         2021-05-30 16:05:57.890  31.0618 -116.6553   5.61  2.87        1
# 3         2019-10-30 02:59:38.290  31.0645 -115.9798   5.25  2.00        1
# 4         2011-07-15 17:07:00.790  31.0625 -115.6812   3.17  2.75        1
# ...                           ...      ...       ...    ...   ...      ...
# 249833    2004-06-18 06:44:13.780  43.9847 -113.7844   9.00  3.30        1
# 249834    2020-09-05 02:16:46.130  43.9846 -113.7388  10.00  2.50        2
# 249835    2020-12-17 22:06:01.130  43.9908 -114.9578  10.00  2.50        2
# 249836    2020-10-17 14:28:28.330  43.9984 -114.4126  10.00  2.50        2
# 249837    1986-09-30 16:11:53.500  43.9960 -113.9420   5.00  3.60        1
#
#            event_id  weight
# src_index
# ...

# %%
SR.rec_points
# Out:
#          src_index  rec_index staname     stla      stlo    stel phase  \
# 0                0        791  BC_SPX  31.0451 -115.4660  2835.0     P
# 1                0        855  BC_SFX  31.0376 -114.8510    39.0     P
# 2                1       1204  BC_VTX  31.3914 -115.7840   746.0     P
# 3                2       1204  BC_VTX  31.3914 -115.7840   746.0     P
# 4                3       1204  BC_VTX  31.3914 -115.7840   746.0     P
# ...            ...        ...     ...      ...       ...     ...   ...
# 5020613     249835          1    HLID  43.5625 -114.4138  1772.0     P
# 5020614     249835          2    MFID  43.4151 -115.8278  1302.0     P
# 5020615     249836          1    HLID  43.5625 -114.4138  1772.0     P
# 5020616     249836          2    CNCI  43.9290 -113.4530  1914.0     P
# 5020617     249837          1     HPI  43.7114 -113.0970  2597.0     P
#
#          dist_deg      tt  weight
# 0           20.37   4.645     1.0
# 1           38.18   7.102     1.0
# ...

# %%
# plot source locations
